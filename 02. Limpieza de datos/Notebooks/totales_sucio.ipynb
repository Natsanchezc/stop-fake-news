# %%
import pandas as pd
import numpy as np

# %%
falsas1 = pd.read_csv('data_emt_limpio_2.csv')
print(falsas1.info())
falsas1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1631 entries, 0 to 1630
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          1631 non-null   object
#  1   Hipervínculo       1631 non-null   object
#  2   Fecha publicación  1631 non-null   object
#  3   Titular            1631 non-null   object
#  4   Subtítulo          1544 non-null   object
#  5   Cuerpo             1631 non-null   object
#  6   Categoría          0 non-null      float64
#  7   Target             1631 non-null   int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 102.1+ KB
# None
#         Periódico                                       Hipervínculo  \
# 0  El Mundo Today  https://www.elmundotoday.com/2011/01/la-crisis...
# 1  El Mundo Today  https://www.elmundotoday.com/2011/01/neutrex-n...
# 2  El Mundo Today  https://www.elmundotoday.com/2011/01/las-bajas...
# ...

# %%
falsas2 = pd.read_csv('data_haynoticia_1.csv')
print(falsas2.info())
falsas2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          100 non-null    object
#  1   Hipervínculo       100 non-null    object
#  2   Fecha publicación  100 non-null    object
#  3   Titular            100 non-null    object
#  4   Subtítulo          0 non-null      float64
#  5   Cuerpo             99 non-null     object
#  6   Categoría          100 non-null    object
#  7   Target             100 non-null    int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.4+ KB
# None
#        Periódico                                       Hipervínculo  \
# 0  HayNoticia.es  https://haynoticia.es/el-gobierno-decreta-el-e...
# 1  HayNoticia.es  https://haynoticia.es/el-gobierno-recomienda-m...
# 2  HayNoticia.es  https://haynoticia.es/vox-propone-que-se-prohi...
# ...

# %%
falsas3 = pd.read_csv('data_haynoticia_2.csv')
print(falsas3.info())
falsas3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 933 entries, 0 to 932
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          933 non-null    object
#  1   Hipervínculo       933 non-null    object
#  2   Fecha publicación  933 non-null    object
#  3   Titular            933 non-null    object
#  4   Subtítulo          0 non-null      float64
#  5   Cuerpo             932 non-null    object
#  6   Categoría          933 non-null    object
#  7   Target             933 non-null    int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 58.4+ KB
# None
#        Periódico                                       Hipervínculo  \
# 0  HayNoticia.es  https://haynoticia.es/el-gobierno-decreta-el-e...
# 1  HayNoticia.es  https://haynoticia.es/el-gobierno-recomienda-m...
# 2  HayNoticia.es  https://haynoticia.es/vox-propone-que-se-prohi...
# ...

# %%
falsas = pd.concat([falsas1, falsas2, falsas3]).reset_index()
print(falsas.info())
falsas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              2664 non-null   int64
#  1   Periódico          2664 non-null   object
#  2   Hipervínculo       2664 non-null   object
#  3   Fecha publicación  2664 non-null   object
#  4   Titular            2664 non-null   object
#  5   Subtítulo          1544 non-null   object
#  6   Cuerpo             2662 non-null   object
#  7   Categoría          1033 non-null   object
#  8   Target             2664 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 187.4+ KB
# None
#    index       Periódico                                       Hipervínculo  \
# 0      0  El Mundo Today  https://www.elmundotoday.com/2011/01/la-crisis...
# 1      1  El Mundo Today  https://www.elmundotoday.com/2011/01/neutrex-n...
# ...

# %%
falsas.Cuerpo.str.len().mean()
# longitud media de los cuerpos en las falsas
# Out:
# 1519.3339594290007

# %%
verdaderas1 = pd.read_csv('data_eldiarioes_1.csv')
print(verdaderas1.info())
verdaderas1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          172 non-null    object
#  1   Hipervínculo       172 non-null    object
#  2   Fecha publicación  169 non-null    object
#  3   Titular            171 non-null    object
#  4   Subtítulo          154 non-null    object
#  5   Cuerpo             169 non-null    object
#  6   Categoría          172 non-null    object
#  7   Target             172 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 10.9+ KB
# None
#      Periódico                                       Hipervínculo  \
# 0  ElDiario.es  https://www.eldiario.es/politica/politica-dire...
# 1  ElDiario.es  https://www.eldiario.es/politica/debates-elect...
# 2  ElDiario.es  https://www.eldiario.es/politica/pp-recupera-l...
# ...

# %%
verdaderas2 = pd.read_csv('data_elmundo_1.csv')
print(verdaderas2.info())
verdaderas2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          1000 non-null   object
#  1   Hipervínculo       1000 non-null   object
#  2   Fecha publicación  998 non-null    object
#  3   Titular            1000 non-null   object
#  4   Subtítulo          909 non-null    object
#  5   Cuerpo             993 non-null    object
#  6   Categoría          1000 non-null   object
#  7   Target             1000 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 62.6+ KB
# None
#   Periódico                                       Hipervínculo  \
# 0   ElMundo  https://www.elmundo.es/ciencia-y-salud/salud/2...
# 1   ElMundo  https://www.elmundo.es/ciencia-y-salud/salud/2...
# 2   ElMundo  https://www.elmundo.es/television/momentvs/202...
# 3   ElMundo  https://www.elmundo.es/yodona/moda/2022/01/01/...
# ...

# %%
verdaderas3 = pd.read_csv('data_elmundo_2.csv')
print(verdaderas3.info())
verdaderas3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          1000 non-null   object
#  1   Hipervínculo       1000 non-null   object
#  2   Fecha publicación  998 non-null    object
#  3   Titular            1000 non-null   object
#  4   Subtítulo          904 non-null    object
#  5   Cuerpo             975 non-null    object
#  6   Categoría          998 non-null    object
#  7   Target             1000 non-null   int64
# dtypes: int64(1), object(7)
# memory usage: 62.6+ KB
# None
#   Periódico                                       Hipervínculo  \
# 0   ElMundo  https://www.elmundo.es/viajes/espana/2022/02/1...
# 1   ElMundo  https://www.elmundo.es/loc/famosos/2022/02/15/...
# 2   ElMundo  https://www.elmundo.es/andalucia/2022/02/15/62...
# 3   ElMundo  https://www.elmundo.es/yodona/lifestyle/2022/0...
# ...

# %%
verdaderas4 = pd.read_csv('data_elpais_4.csv')
print(verdaderas4.info())
verdaderas4.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          500 non-null    object
#  1   Hipervínculo       500 non-null    object
#  2   Fecha publicación  495 non-null    object
#  3   Titular            500 non-null    object
#  4   Subtítulo          500 non-null    object
#  5   Cuerpo             496 non-null    object
#  6   Categoría          500 non-null    object
#  7   Target             500 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.4+ KB
# None
#   Periódico                                       Hipervínculo  \
# 0   El País  https://elpais.com/espana/2022-10-19/el-pp-adm...
# 1   El País  https://elpais.com/deportes/2022-06-05/el-fond...
# 2   El País  https://elpais.com/cultura/2022-09-16/era-sexo...
# 3   El País  https://elpais.com/internacional/2022-08-01/en...
# ...

# %%
verdaderas5 = pd.read_csv('data_elpais_5.csv')
print(verdaderas5.info())
verdaderas5.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          500 non-null    object
#  1   Hipervínculo       500 non-null    object
#  2   Fecha publicación  498 non-null    object
#  3   Titular            500 non-null    object
#  4   Subtítulo          499 non-null    object
#  5   Cuerpo             498 non-null    object
#  6   Categoría          500 non-null    object
#  7   Target             500 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.4+ KB
# None
#   Periódico                                       Hipervínculo  \
# 0   El País  https://elpais.com/deportes/2022-04-25/el-ulti...
# 1   El País  https://elpais.com/cultura/2022-06-14/jordi-so...
# 2   El País  https://elpais.com/planeta-futuro/2022-09-15/l...
# 3   El País  https://elpais.com/deportes/mundial-futbol/202...
# ...

# %%
verdaderas6 = pd.read_csv('data_elpais_6.csv')
print(verdaderas6.info())
verdaderas6.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          500 non-null    object
#  1   Hipervínculo       500 non-null    object
#  2   Fecha publicación  499 non-null    object
#  3   Titular            500 non-null    object
#  4   Subtítulo          500 non-null    object
#  5   Cuerpo             497 non-null    object
#  6   Categoría          500 non-null    object
#  7   Target             500 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.4+ KB
# None
#   Periódico                                       Hipervínculo  \
# 0   El País  https://elpais.com/gente/2022-07-15/vida-y-oca...
# 1   El País  https://elpais.com/cultura/2022-09-08/elena-an...
# 2   El País  https://elpais.com/deportes/es-laliga/2022-03-...
# 3   El País  https://elpais.com/economia/2022-12-21/los-fun...
# ...

# %%
verdaderas7 = pd.read_csv('data_elpais_7.csv')
print(verdaderas7.info())
verdaderas7.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Periódico          500 non-null    object
#  1   Hipervínculo       500 non-null    object
#  2   Fecha publicación  500 non-null    object
#  3   Titular            499 non-null    object
#  4   Subtítulo          499 non-null    object
#  5   Cuerpo             495 non-null    object
#  6   Categoría          500 non-null    object
#  7   Target             500 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.4+ KB
# None
#   Periódico                                       Hipervínculo  \
# 0   El País  https://elpais.com/deportes/2022-07-12/alemani...
# 1   El País  https://elpais.com/deportes/2022-04-03/louis-v...
# 2   El País  https://elpais.com/economia/2022-04-05/llega-l...
# 3   El País  https://elpais.com/espana/comunidad-valenciana...
# ...

# %%
verdaderas = pd.concat([verdaderas1, verdaderas2, verdaderas3, verdaderas4, verdaderas5, verdaderas6, verdaderas7]).reset_index()
print(verdaderas.info())
verdaderas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4172 entries, 0 to 4171
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              4172 non-null   int64
#  1   Periódico          4172 non-null   object
#  2   Hipervínculo       4172 non-null   object
#  3   Fecha publicación  4157 non-null   object
#  4   Titular            4170 non-null   object
#  5   Subtítulo          3965 non-null   object
#  6   Cuerpo             4123 non-null   object
#  7   Categoría          4170 non-null   object
#  8   Target             4172 non-null   int64
# dtypes: int64(2), object(7)
# memory usage: 293.5+ KB
# None
#    index    Periódico                                       Hipervínculo  \
# 0      0  ElDiario.es  https://www.eldiario.es/politica/politica-dire...
# 1      1  ElDiario.es  https://www.eldiario.es/politica/debates-elect...
# ...

# %%
falsas = falsas.dropna(subset=['Cuerpo'])

# %%
verdaderas = verdaderas.dropna(subset=['Cuerpo'])

# %%
df_sucio = pd.concat([falsas, verdaderas]).reset_index()
df_sucio
# Out:
#       level_0  index       Periódico  \
# 0           0      0  El Mundo Today
# 1           1      1  El Mundo Today
# 2           2      2  El Mundo Today
# 3           3      3  El Mundo Today
# 4           4      4  El Mundo Today
# ...       ...    ...             ...
# 6780     4167    495         El País
# 6781     4168    496         El País
# 6782     4169    497         El País
# 6783     4170    498         El País
# 6784     4171    499         El País
#
#                                            Hipervínculo Fecha publicación  \
# 0     https://www.elmundotoday.com/2011/01/la-crisis...        2011-01-30
# 1     https://www.elmundotoday.com/2011/01/neutrex-n...        2011-01-28
# 2     https://www.elmundotoday.com/2011/01/las-bajas...        2011-01-27
# 3     https://www.elmundotoday.com/2011/01/encuentra...        2011-01-27
# 4     https://www.elmundotoday.com/2011/01/el-gobier...        2011-01-25
# ...

# %%
df_sucio = df_sucio.drop(columns = ['level_0', 'index'])
df_sucio.to_csv('totales_sin_limpiar.csv', index = False)
