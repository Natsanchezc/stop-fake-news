# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
df_emt1 = pd.read_csv("data_emt_1.csv")
df_emt2 = pd.read_csv("data_emt_2.csv")
df_emt3 = pd.read_csv("data_emt_3.csv")
df_emt4 = pd.read_csv("data_emt_4.csv")
df_emt5 = pd.read_csv("data_emt_5.csv")
df_emt6 = pd.read_csv("data_emt_6.csv")

# %%
df_emt1
#df_emt6.shape
# Out:
#           Periódico                                       Hipervínculo  \
# 0    El Mundo Today  https://www.elmundotoday.com/2011/01/la-crisis...
# 1    El Mundo Today  https://www.elmundotoday.com/2011/01/neutrex-n...
# 2    El Mundo Today  https://www.elmundotoday.com/2011/01/las-bajas...
# 3    El Mundo Today  https://www.elmundotoday.com/2011/01/encuentra...
# 4    El Mundo Today  https://www.elmundotoday.com/2011/01/el-gobier...
# ..              ...                                                ...
# 195  El Mundo Today  https://www.elmundotoday.com/2012/03/tirotean-...
# 196  El Mundo Today  https://www.elmundotoday.com/2012/03/el-tio-es...
# 197  El Mundo Today  https://www.elmundotoday.com/2012/03/antonio-l...
# 198  El Mundo Today  https://www.elmundotoday.com/2012/03/la-puta-d...
# 199  El Mundo Today  https://www.elmundotoday.com/2012/03/los-recor...
#
#     Fecha publicación                                            Titular  \
# ...

# %%
df_emt = pd.concat([df_emt1, df_emt2, df_emt3, df_emt4, df_emt5, df_emt6])

# %%
df_emt = df_emt.reset_index(drop=True)

# %%
df_emt
# Out:
#            Periódico                                       Hipervínculo  \
# 0     El Mundo Today  https://www.elmundotoday.com/2011/01/la-crisis...
# 1     El Mundo Today  https://www.elmundotoday.com/2011/01/neutrex-n...
# 2     El Mundo Today  https://www.elmundotoday.com/2011/01/las-bajas...
# 3     El Mundo Today  https://www.elmundotoday.com/2011/01/encuentra...
# 4     El Mundo Today  https://www.elmundotoday.com/2011/01/el-gobier...
# ...              ...                                                ...
# 2102  El Mundo Today  https://www.elmundotoday.com/2023/07/un-hombre...
# 2103  El Mundo Today  https://www.elmundotoday.com/2023/07/pedro-san...
# 2104  El Mundo Today  https://www.elmundotoday.com/2023/07/el-psoe-p...
# 2105  El Mundo Today  https://www.elmundotoday.com/2023/07/que-es-lo...
# 2106  El Mundo Today  https://www.elmundotoday.com/2023/07/5-recetas...
#
#      Fecha publicación                                            Titular  \
# ...

# %%
df_emt.to_csv("data_emt.csv", index=False)
